# %%
import requests
import json
import pandas as pd

from time import sleep
from random import random

# %%
def get_json_response(url):
    response = requests.get(url)
    json = response.json()
    return json, response

def df_from_json(json, min_rating = 0, keys = ['name', 'formatted_address', 'opening_hours', 'price_level', 'rating']):
    data = [[i[k] if k in i.keys() else None for k in keys] for i in json['results']]
    df = pd.DataFrame.from_records(data, columns=keys)
    
    #Filter for rating
    df = df[df['rating'] >= min_rating]
    
    return df

# %%
def get_businesses(query, api_key, min_rating=0.0, max_results = 30):

    base_url = 'https://maps.googleapis.com/maps/api/place/textsearch/json?'
    url = base_url + f'query={query}&key={api_key}'

    json, response = get_json_response(url)
    df = df_from_json(json, min_rating=min_rating)


    if 'next_page_token' in json.keys():
        nxt = json['next_page_token']
        while len(df) < max_results:
            new_url = base_url+f'key={api_key}&pagetoken={nxt}'

            json, response = get_json_response(new_url)
            while response.json().get('status') != 'OK':
                #More info not available yet - so, wait.
                sleep(random())
                #Try again:
                json, response = get_json_response(new_url)

            #Cast result to df and append to list.
            df_more = df_from_json(json, min_rating=min_rating)

            df = pd.concat([df, df_more], axis=0).reset_index(drop=True)

            #Are there even MORE results?
            if 'next_page_token' in json.keys():
                nxt = json['next_page_token']    
            else:
                #No more results!
                print('No more results!')
                break
    else:
        print('Only one page of results!')
        
    return df.iloc[:max_results]

# %%
freeform_query = 'food near 108 W 81st Street NYC'
query = '+'.join(freeform_query.split())
api_key = 'AIzaSyCcpnnkVdmrXkDm7Ow8pe5aEBq9OIv98kw'

get_businesses(query, api_key)
# Out:
#                                    name  \
# 0                  Uno Pizzeria & Grill
# 1                                 Spice
# 2                      The Milling Room
# 3                                 Flame
# 4                           Juice Press
# 5           Lokal Mediterranean Kitchen
# 6                        Mexikosher NYC
# 7                                Ashoka
# 8                Spring Natural Kitchen
# 9            Sarabeth's Upper West Side
# 10  Tarallucci e Vino - Upper West Side
# 11                Olma Restaurant & Bar
# 12                             Cilantro
# 13                               Amused
# 14               Senn Thai Comfort Food
# 15                           Haru Sushi
# 16       Luke's Lobster Upper West Side
# 17                               Momoya
# 18                        Crave Fishbar
# 19                       Peacefood Cafe
# 20                        Gari Columbus
# 21                                  Jin
# 22                  Blossom on Columbus
# 23                               Swagat
# 24                        Osteria Cotta
# 25                      Jacob's Pickles
# 26                    Land Thai Kitchen
# 27                         Flor de Mayo
# 28                            Westville
# 29                          Ray's Pizza
#
#                                     formatted_address        opening_hours  \
# 0           432 Columbus Ave, New York, NY 10024, USA   {'open_now': True}
# 1   435 AMSTERDAM AVENUE (AT, W 81st St, New York,...  {'open_now': False}
# 2           446 Columbus Ave, New York, NY 10024, USA  {'open_now': False}
# 3   5502, 100 W 82nd St, New York, NY 10024, Unite...  {'open_now': False}
# 4               73 W 82nd St, New York, NY 10024, USA   {'open_now': True}
# 5           473 Columbus Ave, New York, NY 10024, USA  {'open_now': False}
# 6              100 W 83rd St, New York, NY 10024, USA   {'open_now': True}
# 7           489 Columbus Ave, New York, NY 10024, USA  {'open_now': False}
# 8           474 Columbus Ave, New York, NY 10024, USA   {'open_now': True}
# 9          423 Amsterdam Ave, New York, NY 10024, USA   {'open_now': True}
# 10          475 Columbus Ave, New York, NY 10024, USA   {'open_now': True}
# 11         420 Amsterdam Ave, New York, NY 10024, USA  {'open_now': False}
# 12          485 Columbus Ave, New York, NY 10024, USA  {'open_now': False}
# 13             142 W 83rd St, New York, NY 10024, USA   {'open_now': True}
# 14         452 Amsterdam Ave, New York, NY 10024, USA  {'open_now': False}
# 15         433 Amsterdam Ave, New York, NY 10024, USA  {'open_now': False}
# 16         426 Amsterdam Ave, New York, NY 10024, USA   {'open_now': True}
# 17         427 Amsterdam Ave, New York, NY 10024, USA  {'open_now': False}
# 18         428 Amsterdam Ave, New York, NY 10024, USA  {'open_now': False}
# 19         460 Amsterdam Ave, New York, NY 10024, USA   {'open_now': True}
# 20          370 Columbus Ave, New York, NY 10024, USA  {'open_now': False}
# 21         462 Amsterdam Ave, New York, NY 10024, USA  {'open_now': False}
# 22          507 Columbus Ave, New York, NY 10024, USA  {'open_now': False}
# 23        411A Amsterdam Ave, New York, NY 10024, USA  {'open_now': False}
# 24          513 Columbus Ave, New York, NY 10024, USA  {'open_now': False}
# 25         509 Amsterdam Ave, New York, NY 10024, USA   {'open_now': True}
# 26         450 Amsterdam Ave, New York, NY 10024, USA  {'open_now': False}
# 27         484 Amsterdam Ave, New York, NY 10024, USA  {'open_now': False}
# 28                            New York, NY 10024, USA                 None
# 29          462 Columbus Ave, New York, NY 10024, USA   {'open_now': True}
#
#     price_level  rating
# 0           2.0     4.1
# 1           2.0     4.0
# 2           3.0     4.5
# 3           2.0     4.3
# 4           2.0     4.2
# 5           2.0     4.4
# 6           2.0     4.3
# 7           2.0     4.4
# 8           2.0     4.2
# 9           2.0     4.2
# 10          2.0     4.3
# 11          2.0     4.6
# 12          2.0     4.3
# 13          2.0     4.2
# 14          2.0     4.5
# 15          2.0     4.3
# 16          2.0     4.4
# 17          2.0     4.4
# 18          2.0     4.5
# 19          2.0     4.4
# 20          4.0     4.5
# 21          2.0     4.4
# 22          2.0     4.4
# 23          2.0     4.3
# 24          2.0     4.4
# 25          2.0     4.6
# 26          2.0     4.2
# 27          2.0     4.4
# 28          NaN     0.0
# 29          1.0     3.9
